# %%
import csv


with open('LMPD_OP_BIAS_7.csv') as rawhcdata:
    reader = csv.DictReader(rawhcdata)
    for row in reader:
        print(row)
# Out:
# OrderedDict([('ID', '1'), ('INCIDENT_NUMBER', '80-10-000286'), ('DATE_REPORTED', '2010-01-02 14:34:00'), ('DATE_OCCURED', '2010-01-02 00:00:00'), ('CRIME_TYPE', 'VANDALISM'), ('BIAS_MOTIVATION_GROUP', 'ANTI-BLACK                                   '), ('BAIS_TARGETED_AGAINST', 'OTHER PROPERTY                                         '), ('UOR_DESC', 'CRIMINAL MISCHIEF-3RD DEGREE'), ('NIBRS_CODE', '290'), ('UCR_HIERARCHY', 'PART II'), ('ATT_COMP', 'COMPLETED'), ('LMPD_DIVISION', '7TH DIVISION'), ('LMPD_BEAT', '711'), ('PREMISE_TYPE', 'RESIDENCE / HOME'), ('BLOCK_ADDRESS', '9400 BLOCK PLUMWOOD RD                                      '), ('City', 'LOUISVILLE'), ('ZIP_CODE', '40291')])
# ...
